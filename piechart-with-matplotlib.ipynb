# %% [markdown]
# <div style="background-color:#F8D7DA; color:#721C24; padding:20px; border-radius:10px; text-align:center;">
#     <h3 style="font-weight:bold; margin-top:0; font: 30px Arial;">🔴 Pie Chart</h3>
# </div>
# <br>
# <div style="background-color:green; color:white; padding:20px; border-radius:10px; text-align:center;">
# <p style="font: 18px Arial, sans-serif;">🔴 A Pie Chart is a circle divided into sectors that each represent a proportion of the whole.</p>
# <p style="font: 18px Arial, sans-serif;">🔴 Pie charts are particularly effective when displaying data with relatively few categories, as they allow the viewer to quickly and easily compare the relative sizes of each category. They are also useful for highlighting one or more categories that are particularly large or small compared to the others.</p>
# </div>

# %%
# first import library
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# Load data
data = pd.read_csv('simpletelecom.csv')
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# # Data preprocessing

# %%
#check null values 
data.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
data.describe
# Out:
# <bound method NDFrame.describe of       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# ...

# %%
data.isnull()
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0          False   False          False    False       False   False
# 1          False   False          False    False       False   False
# 2          False   False          False    False       False   False
# 3          False   False          False    False       False   False
# 4          False   False          False    False       False   False
# ...          ...     ...            ...      ...         ...     ...
# 7038       False   False          False    False       False   False
# 7039       False   False          False    False       False   False
# 7040       False   False          False    False       False   False
# 7041       False   False          False    False       False   False
# 7042       False   False          False    False       False   False
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
# check all columns name 
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
# print all each columns unique category
print(f"Unique Values for categorical columns:")
for col in data.select_dtypes(include='object'):
  print(f"  - {col}: {data[col].unique()}\n")
# Out:
# Unique Values for categorical columns:
#   - customerID: ['7590-VHVEG' '5575-GNVDE' '3668-QPYBK' ... '4801-JZAZL' '8361-LTMKD'
#  '3186-AJIEK']
#
#   - gender: ['Female' 'Male']
#
#   - Partner: ['Yes' 'No']
#
#   - Dependents: ['No' 'Yes']
#
#   - PhoneService: ['No' 'Yes']
#
#   - MultipleLines: ['No phone service' 'No' 'Yes']
#
#   - InternetService: ['DSL' 'Fiber optic' 'No']
#
#   - OnlineSecurity: ['No' 'Yes' 'No internet service']
#
#   - OnlineBackup: ['Yes' 'No' 'No internet service']
#
#   - DeviceProtection: ['No' 'Yes' 'No internet service']
#
#   - TechSupport: ['No' 'Yes' 'No internet service']
#
#   - StreamingTV: ['No' 'Yes' 'No internet service']
#
#   - StreamingMovies: ['No' 'Yes' 'No internet service']
#
#   - Contract: ['Month-to-month' 'One year' 'Two year']
#
#   - PaperlessBilling: ['Yes' 'No']
#
#   - PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
#
# ...

# %% [markdown]
# # make new dataset for show in chart

# %%
# here groupby Payment Method and make a new data 
newdata = data.groupby('PaymentMethod').size().rename_axis('PaymentMethodCategory').reset_index(name='Count')
newdata.head()
# Out:
#        PaymentMethodCategory  Count
# 0  Bank transfer (automatic)   1544
# 1    Credit card (automatic)   1522
# 2           Electronic check   2365
# 3               Mailed check   1612

# %%
newdata = data.groupby('SeniorCitizen').size().rename_axis('SeniorCitizen').reset_index(name='Count')
newdata
# Out:
#    SeniorCitizen  Count
# 0              0   5901
# 1              1   1142

# %%
newdata = data.groupby('SeniorCitizen').size()
newdata
type(newdata)
# Out:
# pandas.core.series.Series

# %%
# make 2 variable for labels and values 
labels = newdata.PaymentMethodCategory
values = newdata.Count
type(values)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Visualization

# %%
# Simple Pie Chart
plt.figure(figsize=(5,4))
# Create a pieplot
plt.pie(values)
plt.show()

# %% [markdown]
# # Add labels

# %%
# Label distance: gives the space between labels and the center of the pie
plt.figure(figsize=(5,4))
plt.pie(values, labels=labels, labeldistance=0.5);
plt.show();

# %% [markdown]
# # Add title

# %%
plt.figure(figsize=(5,4))
# Label distance: gives the space between labels and the center of the pie
plt.pie(values, labels=labels, labeldistance=1.15);
plt.title("Pie Chart", size=15)
plt.show();

# %% [markdown]
# # Customize wedges
# - customize wedges to get some blank spaces around them

# %%
plt.figure(figsize=(5,4))
color = ['lightcoral', 'rosybrown']
plt.pie(values, labels=labels, labeldistance=1.15, wedgeprops = { 'linewidth' : 2, 'edgecolor' : 'white' },colors=color)
plt.title("Customize wedges", size=15)
plt.show()

# %% [markdown]
# #  Custom Color

# %%
color = ['lightcoral', 'rosybrown', 'sandybrown', 'navajowhite', 'gold',
        'khaki', 'lightskyblue', 'turquoise', 'lightslategrey', 'thistle', 'pink']
plt.figure(figsize=(5,4))
plt.title("Custom Color", size=15)
plt.pie(values, labels=labels, labeldistance=1.15, wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' }, colors=color);
plt.show()

# %% [markdown]
# # Auto-label slices
# - Pass a function or format string to autopct(auto percentages) to label slices.

# %%
plt.figure(figsize=(5,4))
plt.pie(values, labels=labels, 
        labeldistance=1.15, 
        wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' }, 
        autopct='%2.2f%%');
plt.title("Custom Color", size=15)
plt.show();

# %% [markdown]
# # Swap label and autopct text positions

# %%
plt.figure(figsize=(5,4))
plt.pie(values, labels=labels, 
        wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' }, 
        autopct='%1.1f%%',
        pctdistance=1.25, 
        labeldistance=.6);
plt.show();

# %% [markdown]
# # Explode, shade, and rotate slices

# %%
plt.figure(figsize=(5,4))
explode = (0, 0, 0.1, 0)  # only "explode" the Electronic check
plt.pie(values, labels=labels, 
        explode=explode,
        labeldistance=1.15, 
        wedgeprops = { 'linewidth' : 1, 'edgecolor' : 'white' }, 
        autopct='%1.1f%%',
        shadow=True, startangle=45)
plt.show()

# %% [markdown]
# # Add legend

# %%
plt.figure(figsize=(10,10))

plt.pie(values, 
        wedgeprops = { 'linewidth' : 1, 'edgecolor' : 'white' }, 
        autopct='%1.1f%%',)
plt.legend(labels,loc="best", fontsize=12)

plt.show()

# %% [markdown]
# # Legend  Header add

# %%
plt.figure(figsize=(18,10))

plt.pie(values, 
        wedgeprops = { 'linewidth' : 1, 'edgecolor' : 'white' }, 
        autopct='%1.1f%%',)
plt.legend(labels, loc='best', fontsize=12,title = "Category")

plt.show()

# %% [markdown]
# # Donut chart in pic chart

# %%
plt.figure(figsize=(5,4))

explode = (0, 0, 0.1, 0)  # only "explode" the Electronic check
plt.pie(values, labels=labels,  
        wedgeprops = { 'linewidth' : 1, 'edgecolor' : 'white' }, 
        autopct='%1.1f%%',
        startangle=45)

#draw circle
centre_circle = plt.Circle((0,0),0.80,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.tight_layout()

plt.show()

# %% [markdown]
# ## change positions of labels
# using  pctdistance=0.85,

# %%
plt.figure(figsize=(5,4))
explode = (0, 0, 0.1, 0)  # only "explode" the Electronic check
plt.pie(values, labels=labels,  
        wedgeprops = { 'linewidth' : 1, 'edgecolor' : 'white' }, 
        autopct='%1.1f%%',
        pctdistance=0.85,
        startangle=45)

#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.show()

# %% [markdown]
# # Double Pie Chart
# - For this you need to groupby the data  2 times. First group 2 category variable and next group only main variable

# %%
# here groupby Payment Method and make a new data 
newdata2 = data.groupby(['PaymentMethod','gender']).size().reset_index(name='Count')
newdata2.head(10)
# Out:
#                PaymentMethod  gender  Count
# 0  Bank transfer (automatic)  Female    788
# 1  Bank transfer (automatic)    Male    756
# 2    Credit card (automatic)  Female    752
# 3    Credit card (automatic)    Male    770
# 4           Electronic check  Female   1170
# 5           Electronic check    Male   1195
# 6               Mailed check  Female    778
# 7               Mailed check    Male    834

# %%
newdata3 = data.groupby('PaymentMethod').size().reset_index(name='Count')
newdata3.head(10)
# Out:
#                PaymentMethod  Count
# 0  Bank transfer (automatic)   1544
# 1    Credit card (automatic)   1522
# 2           Electronic check   2365
# 3               Mailed check   1612

# %%
#Plot
colors = ['#ff6666', '#ffcc99', '#99ff99', '#66b3ff']
colors_gender = ['g','y', 'g','y','g','y','g','y',]
plt.pie(newdata3.Count, labels=newdata3.PaymentMethod, colors=colors, startangle=90,frame=True,radius=1,autopct='%1.1f%%',
        pctdistance=0.85,)
plt.pie(newdata2.Count,colors=colors_gender,autopct='%1.1f%%',
        startangle=90, radius=.7 )
centre_circle = plt.Circle((0,0),.2,color='black', fc='white',linewidth=0,)
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.text(2, 1, "Green = Female \nYellow = Male ", bbox=dict(facecolor='white', alpha=0.5))
plt.show()

# %% [markdown]
# #  Make a function  for showing

# %%
def plot_pie_charts(x, y, title):
    # more muted color 
    c = ['lightcoral', 'rosybrown', 'sandybrown', 'navajowhite', 'gold',
        'khaki', 'lightskyblue', 'turquoise', 'lightslategrey', 'thistle', 'pink']
    plt.figure(figsize=(9,9))
    plt.title(title, size=20)
    plt.pie(x, labels=y, labeldistance=1.15, wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' }, colors=c,autopct='%1.1f%%');
    plt.legend(y, loc='best', fontsize=12)
    plt.show()

# %% [markdown]
# # First Chart using function

# %%
plot_pie_charts(values, labels,"Payment Method")

# %% [markdown]
# # Second Chart using function

# %%
# here groupby gender and make a new data 
genderD = data.groupby('gender').size().rename_axis('genderc').reset_index(name='Count')
genderD.head()
# Out:
#   genderc  Count
# 0  Female   3488
# 1    Male   3555

# %%
labels = genderD.genderc
values = genderD.Count

# %%
# call pie chart function
plot_pie_charts(values, labels,"Gender")

# %%
plt.pie(values, labels=labels, 
        wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' }, 
        autopct='%1.1f%%',
        pctdistance=1.25, 
        labeldistance=.6);
plt.show();
