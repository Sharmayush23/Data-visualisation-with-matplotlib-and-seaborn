# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y1 = [10, 15, 7, 12]
y2 = [5, 8, 10, 6]

plt.subplot(2, 1, 1)  # 2 rows, 1 column, subplot 1
plt.plot(x, y1)
plt.title('Subplot 1')

plt.subplot(2, 1, 2)  # 2 rows, 1 column, subplot 2
plt.plot(x, y2)
plt.title('Subplot 2')

plt.tight_layout()  # Adjust layout to prevent overlapping
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

n = 16
X = np.arange(n)
Y1 = (1-X/float(n)) * np.random.uniform(0.5,1.0,n)
Y2 = (1-X/float(n)) * np.random.uniform(0.5,1.0,n)
plt.bar(X, +Y1, facecolor='#9999ff', edgecolor='white')
plt.bar(X, -Y2, facecolor='#ff9999', edgecolor='white')
plt.xlim(-.5,n), plt.xticks([])
plt.ylim(-1,+1), plt.yticks([])

plt.text(-0.05, 1.05, " Bar Plot \n\n",
         horizontalalignment='left',
         verticalalignment='top',
         family='Lint McCree Intl BB',
         size='x-large',
         bbox=dict(facecolor='white', alpha=1.0, width=375, height=65),
         transform = plt.gca().transAxes)

plt.text(-0.05, .975, " Make a bar plot with rectangles ",
         horizontalalignment='left',
         verticalalignment='top',
         family='Lint McCree Intl BB',
         size='medium',
         transform = plt.gca().transAxes)

# plt.savefig('../figures/bar.png', dpi=64)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 13
#      10 plt.xlim(-.5,n), plt.xticks([])
#      11 plt.ylim(-1,+1), plt.yticks([])
# ---> 13 plt.text(-0.05, 1.05, " Bar Plot \n\n",
#      14          horizontalalignment='left',
#      15          verticalalignment='top',
#      16          family='Lint McCree Intl BB',
#      17          size='x-large',
#      18          bbox=dict(facecolor='white', alpha=1.0, width=375, height=65),
#      19          transform = plt.gca().transAxes)
#      21 plt.text(-0.05, .975, " Make a bar plot with rectangles ",
#      22          horizontalalignment='left',
#      23          verticalalignment='top',
#      24          family='Lint McCree Intl BB',
#      25          size='medium',
#      26          transform = plt.gca().transAxes)
#      28 # plt.savefig('../figures/bar.png', dpi=64)
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:3939, in text(x, y, s, fontdict, **kwargs)
#    3935 @_copy_docstring_and_deprecators(Axes.text)
#    3936 def text(
#    3937     x: float, y: float, s: str, fontdict: dict[str, Any] | None = None, **kwargs
#    3938 ) -> Text:
# -> 3939     return gca().text(x, y, s, fontdict=fontdict, **kwargs)
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_axes.py:700, in Axes.text(self, x, y, s, fontdict, **kwargs)
#     632 """
#     633 Add text to the Axes.
#     634
#    (...)
#     690     >>> text(x, y, s, bbox=dict(facecolor='red', alpha=0.5))
#     691 """
#     692 effective_kwargs = {
#     693     'verticalalignment': 'baseline',
#     694     'horizontalalignment': 'left',
#    (...)
#     698     **kwargs,
#     699 }
# --> 700 t = mtext.Text(x, y, text=s, **effective_kwargs)
#     701 if t.get_clip_path() is None:
#     702     t.set_clip_path(self.patch)
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\text.py:155, in Text.__init__(self, x, y, text, color, verticalalignment, horizontalalignment, multialignment, fontproperties, rotation, linespacing, rotation_mode, usetex, wrap, transform_rotates_text, parse_math, antialiased, **kwargs)
#     138 self._text = ''
#     139 self._reset_visual_defaults(
#     140     text=text,
#     141     color=color,
#    (...)
#     153     antialiased=antialiased
#     154 )
# --> 155 self.update(kwargs)
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\text.py:207, in Text.update(self, kwargs)
#     205 ret.extend(super().update(kwargs))
#     206 if bbox is not sentinel:
# --> 207     ret.append(self.set_bbox(bbox))
#     208 return ret
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\text.py:541, in Text.set_bbox(self, rectprops)
#     539     if isinstance(boxstyle, str) and "pad" not in boxstyle:
#     540         boxstyle += ",pad=%0.2f" % pad
# --> 541     self._bbox_patch = FancyBboxPatch(
#     542         (0, 0), 1, 1,
#     543         boxstyle=boxstyle, transform=IdentityTransform(), **props)
#     544 else:
#     545     self._bbox_patch = None
#
# TypeError: FancyBboxPatch.__init__() got multiple values for argument 'width'
