# %%
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt
import csv
from collections import Counter

df=pd.read_csv("nifty50.csv")
df
# Out:
#           Date      Open      High       Low     Close   \
# 0   09-OCT-2023  19539.45  19588.95  19480.50  19512.35
# 1   10-OCT-2023  19565.60  19717.80  19565.45  19689.85
# 2   11-OCT-2023  19767.00  19839.20  19756.95  19811.35
# 3   12-OCT-2023  19822.70  19843.30  19772.65  19794.00
# 4   13-OCT-2023  19654.55  19805.40  19635.30  19751.05
# ..          ...       ...       ...       ...       ...
# 57  01-JAN-2024  21727.75  21834.35  21680.85  21741.90
# 58  02-JAN-2024  21751.35  21755.60  21555.65  21665.80
# 59  03-JAN-2024  21661.10  21677.00  21500.35  21517.35
# 60  04-JAN-2024  21605.80  21685.65  21564.55  21658.60
# 61  05-JAN-2024  21705.75  21749.60  21629.20  21710.80
#
#     c:\Users\LENOVO\Downloads\archive (3)\most-popular.csv   Turnover (₹ Cr)
# 0                                           165094800               15499.67
# 1                                           216559447               18735.62
# ...

# %%
plt.figure(figsize=(10, 6))
plt.plot([1, 2, 3, 4], [2, 4, 6, 8])  # Example plot
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Example Plot')
plt.show()
