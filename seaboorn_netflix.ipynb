# %%
import pandas as pd 
import seaborn as sns
import csv
import matplotlib as matplotlib
from matplotlib import pyplot as plt

datas=pd.read_csv("most-popular.csv")
datas.head()
# Out:
# Using matplotlib backend: <object object at 0x00000202FF8EC7A0>

# %%
sns.relplot(y='runtime',x='show_title',data=datas)

# %%
sns.relplot(y='runtime',x='show_title',data=datas,hue='category',style="rank")
